# %%
import pandas as pd

# %%
flat = pd.read_csv("/content/sample_data/flats_cleaned.csv")

# %%
house = pd.read_csv("/content/sample_data/house_cleaned.csv")

# %%
df = pd.concat([flat,house],ignore_index=True)

# %%
df.sample(10)
# Out:
#                                     property_name property_type  \
# 3428     3 Bedroom House for sale in Laxman Vihar         house
# 612              3 BHK Flat in Sector 37C Gurgaon          flat
# 2475             3 BHK Flat in Sector 104 Gurgaon          flat
# 2376             2 BHK Flat in Sector 107 Gurgaon          flat
# 2096                          3 BHK Flat in Sohna          flat
# 3725  5 Bedroom House for sale in Nirvana Country         house
# 153              2 BHK Flat in Sector 108 Gurgaon          flat
# 2571             3 BHK Flat in Sector 37C Gurgaon          flat
# 833               3 BHK Flat in Sector 65 Gurgaon          flat
# 2635             2 BHK Flat in Sector 108 Gurgaon          flat
#
#                      society  price  price_per_sqft    area  \
# 3428             independent   0.70          6648.0  1053.0
# 612       imperia the esfera   0.99          5500.0  1800.0
# 2475             zara aavaas   0.65          8519.0   763.0
# ...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.to_csv("gurgaon_properties.csv",index = False)
